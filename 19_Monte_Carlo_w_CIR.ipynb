# %%
import numpy as np 
import pandas as pd
import kit as erk

# %%
# %matplotlib inline
# %load_ext autoreload
# %autoreload 2

# %%
erk.bond_price(5, 100, .05, 12, .03)
# Out:
# ---------------------------------------------------------------------------
# UnboundLocalError                         Traceback (most recent call last)
# Cell In[5], line 1
# ----> 1 erk.bond_price(5, 100, .05, 12,.03)
#
# File ~/Documents/ESSCA | MSc Finance & Data Analyst/Semester 2/9. Introduction to Portfolio Construction/kit.py:637, in bond_price(maturity, principal, coupon_rate, coupon_per_year, discount_rate)
#     633 """
#     634 Return the price of a bond given the maturity, principal, coupon rate, coupon per year, and discount rate
#     635 """
#     636 cf = bond_cash_flows(maturity, principal, coupon_rate, coupon_per_year)
# --> 637 return pv(cf, discount_rate / coupon_per_year)
#
# File ~/Documents/ESSCA | MSc Finance & Data Analyst/Semester 2/9. Introduction to Portfolio Construction/kit.py:290, in pv(flows, r)
#     285 """
#     286 Compute the present value of a sequence of flows given by the time as an index and amount r can be
# ...
