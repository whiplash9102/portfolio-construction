# %% [markdown]
# # Random Walk Generation

# %%
import numpy as np
import pandas as pd

# %%
def gbm(n_years = 10, n_scenarios = 1000, mu=0.07, sigma=0.15, steps_per_year=12, s_0=100.0):
    """ 
    Evoluation of a Stock Price using Geometric Brownian Motion Model
    """
    dt = 1/steps_per_year
    n_steps = int(n_years * steps_per_year)
    xi = np.random.normal(size=(n_steps, n_scenarios))
    rets = mu*dt  + sigma*np.sqrt(dt)*xi
    rets = pd.DataFrame(rets)
    # to prices
    prices = s_0*(1+rets).cumprod()
    return prices

# %%
p = gbm(10, n_scenarios=3)
p.plot()
# Out:
# <Axes: >

# %%
p = gbm(n_years=10, n_scenarios=1000).plot(figsize=(12,6), legend=False)

# %%
def gbm0(n_years = 10, n_scenarios = 1000, mu=0.07, sigma=0.15, steps_per_year=12, s_0=100.0):
    """ 
    Evoluation of a Stock Price using Geometric Brownian Motion Model
    """
    dt = 1/steps_per_year
    n_steps = int(n_years * steps_per_year)
    xi = np.random.normal(size=(n_steps, n_scenarios))
    rets = mu*dt  + sigma*np.sqrt(dt)*xi
    rets = pd.DataFrame(rets)
    # to prices
    prices = s_0*(1+rets).cumprod()
    return prices

# %%
def gbm1(n_years = 10, n_scenarios = 1000, mu=0.07, sigma=0.15, steps_per_year=12, s_0=100.0):
    """ 
    Evoluation of a Stock Price using Geometric Brownian Motion Model
    """
    dt = 1/steps_per_year
    n_steps = int(n_years * steps_per_year)
    rets_plus_one = np.random.normal(loc=(1+mu*dt), scale=(sigma*np.sqrt(dt)),size=(n_steps, n_scenarios))
    # to prices
    prices = s_0*pd.DataFrame(rets_plus_one.cumprod(axis=0))
    return prices

# %%
gbm1(n_years=10, n_scenarios=20).head()
# Out:
#            0           1           2           3           4           5   \
# 0  100.000000  100.000000  100.000000  100.000000  100.000000  100.000000
# 1   98.060790   99.467734   99.658173   98.593312   98.424966  106.235619
# 2  101.185283  107.734444  100.572863  106.880522  101.832483  102.472621
# 3  103.463254  104.231480  105.497875  106.565959  104.707867  100.542801
# 4   99.206741  112.704893  107.004079  110.980678  103.335887  105.138060
#
#            6           7           8           9           10          11  \
# 0  100.000000  100.000000  100.000000  100.000000  100.000000  100.000000
# 1   96.983956   98.300975   93.514655  107.039400   95.651573   97.412440
# 2   98.763031  107.803398   94.584028  111.662797   93.542860   95.390416
# 3   93.453974  107.960974   94.064037  116.220144   98.370739  104.039736
# 4   92.116448  112.472561   96.097528  116.669084   96.487044   98.885618
#
#            12          13          14          15          16          17  \
# 0  100.000000  100.000000  100.000000  100.000000  100.000000  100.000000
# 1   98.514581  101.872998  104.017815   95.396813   92.603966   99.318441
# 2   97.144358  101.317007  106.299221   94.367684   90.734413   94.769629
# 3   97.599902  107.517655   99.384727   97.009337   93.160589   92.681623
# 4   93.026656  105.964942  102.008108   98.698130   95.157147   92.756361
#
#            18          19
# 0  100.000000  100.000000
# 1   99.434541   95.391653
# 2  102.228369   97.872113
# 3  101.765988   98.817416
# 4  101.266082   99.734381

# %%
def gbm_2(n_years = 10, n_scenarios = 1000, mu=0.07, sigma=0.15, steps_per_year=12, s_0=100.0):
    """ 
    Evoluation of a Stock Price using Geometric Brownian Motion Model
    """
    dt = 1/steps_per_year
    n_steps = int(n_years * steps_per_year)
    rets_plus_one = np.random.normal(loc=(1+mu*dt), scale=(sigma*np.sqrt(dt)),size=(n_steps, n_scenarios))
    rets_plus_one[0]=1
    # to prices
    prices = s_0*pd.DataFrame(rets_plus_one.cumprod(axis=0))
    return prices

# %%
gbm_2(n_scenarios=20).head()
# Out:
#            0           1           2           3           4           5   \
# 0  100.000000  100.000000  100.000000  100.000000  100.000000  100.000000
# 1   98.818144  102.247949  104.053411  104.024170  101.116825  100.296782
# 2   98.621215  103.981191  106.075817  107.256208  107.333234  100.494674
# 3   98.309232   96.529835  103.512857  116.987488  109.186212  105.333051
# 4   99.124723   87.822666  108.091409  117.574286  105.877096  100.758619
#
#            6           7           8           9           10          11  \
# 0  100.000000  100.000000  100.000000  100.000000  100.000000  100.000000
# 1   94.588383   96.671612   91.273658  103.525335  104.949593   95.033885
# 2  101.608174   96.032672   88.234264  109.563254  101.134274   98.266075
# 3  101.169826   93.302595   88.076434  110.343439   99.529859   96.262700
# 4  104.080314   94.475163   89.877892  120.302848   89.474473   88.454754
#
#            12          13          14          15          16          17  \
# 0  100.000000  100.000000  100.000000  100.000000  100.000000  100.000000
# 1  102.107141  101.166060  106.845651  105.256464  109.634449  105.249484
# 2  100.297105   99.107619  104.225201  113.437765  113.165979  101.639163
# 3  112.287994   97.085299  109.926763  117.889296  113.479801  105.228067
# 4  114.683674   94.229060  105.853030  120.819359  110.670250  110.574971
#
#            18          19
# 0  100.000000  100.000000
# 1  103.723984   97.249320
# 2  109.319675  100.502106
# 3  108.673895   96.355061
# 4  109.747885  104.882955
